# %% [markdown]
# Benchmark runs:
# Setup:
# - Benchmarks:
#     - Image processing with 1 fan-out node (flip)
#     - Text-2-Speech Censoring
#     - Video analytics with 6 fan-out node
# - Invocation Rates:
#     - Low invocation rate: 0.1 rps for 15 minutes (90 invocations)
#     - High invocation rate: 1 rps for 10 minutes (600 invocations)
#     - Very high invocation rate: 5 rps for 5 minutes (1500 invocations)
# - Concurrency Limits
#     - 1 concurrency
#     - 10 concurrency
#
# - Measured latencies
#     - End-to-end latency (from when the function is first invoked until the last function has finished execution)
#     - Pub/sub latency (from when message is sent from sender until received - in this case, function starts execution)
#     - Latencies will be served in stacked bar format, with the pub/sub latency stacked from each part of the function
#
# - Amount of data being sent is dependent on the function that calls it (e.g. image processing and video analytics will have a different data size)
# - Pub/sub settings
#     - Topic settings
#         - Schema
#         - Ingestion (topic gets data asynchronously from a cloud storage bucket)
#         - Message retention (up to 7 days)
#         - Export message to BigQuery
#         - Backup to google cloud storage
#         - Message Transform
#         - Encryption
#     - Subscription settings
#         - pull
#         - push
#         - write to BigQuery
#         - write to Cloud storage
#         - message retention
#         - expiration period
#         - ack deadline
#         - transforms
#         - subscription filter
#         - exactly once delivery
#         - ordering
#         - dead lettering
#         - retry policy

# %% [markdown]
# Times
# - Image processing
#     - Low invocation rate (0.1 rps), 15 minute runs
#         - wed sep 24 21:33:21
#         - wed sep 24 21:48:27
#     - Medium invocation rate (1 rps), 10 minute runs
#         - wed sep 24 21:14:13
#         - wed sep 24 21:25:32
#     - High invocation rate (5 rps), 5 minute runs
#         - wed sep 24 23:37:51
#         - wed sep 24 23:45:42
# - Text-2-Speech Censoring
#     - Low invocation rate (0.1 rps), 15 minute runs
#         - Thu sep 25 16:23:51
#         - Thu sep 25 16:38:50
#     - Medium invocation rate (1 rps), 10 minute runs
#         - Thu Sep 25 14:49:30
#         - Thu Sep 25 15:00:03
#     - High invocation rate (5 rps), 5 minute runs
#         - Thu sep 25 00:03:56
#         - Thu sep 25 00:10:36
# - Video Analytics
#     - Low invocation rate (0.1 rps), 15 minute runs
#         - Thu sep 25 22:22:06
#         - Thu sep 25 22:37:02
#     - Medium invocation rate (1 rps), 10 minute runs
#         - Thu sep 25 22:53:33
#         - Thu sep 25 23:04:05
#     - High invocation rate (5 rps), 5 minute runs
#         - Fri Sep 26 00:42:26
#         - Fri Sep 26 00:48:26

# %% [markdown]
# - Image Processing
#     - Results for 'Low (0.1 rps)':
#         - Average End-to-End Time: 2.4746s
#         - Average Pub/Sub Delay:   0.1779s
#     - Results for 'Medium (1 rps)':
#         - Average End-to-End Time: 1.9543s
#         - Average Pub/Sub Delay:   0.2349s
# - Text 2 Speech Censoring
#     - Results for 'High (5 rps)':
#         - Average End-to-End Time: 18.9819s
#         - Average latency of parallel 'profanity' branch: 0.2918s
# - Video Analytics
